# %%
import pandas as pd

# %%
fileName = "dataset2_අඩෝ.csv"
label = 0
data = pd.read_csv(fileName)

# %%
data.head()
# Out:
#             Unnamed: 0                      created_at                   id  \
# 0  1347508753520680962  Fri Jan 08 11:41:36 +0000 2021  1347508753520680962
# 1  1360929538717274115  Sun Feb 14 12:31:01 +0000 2021  1360929538717274115
# 2  1368467258196914176  Sun Mar 07 07:43:13 +0000 2021  1368467258196914176
# 3  1366583603610591237  Tue Mar 02 02:58:15 +0000 2021  1366583603610591237
# 4  1366256111167307779  Mon Mar 01 05:16:55 +0000 2021  1366256111167307779
#
#                 id_str                                          full_text  \
# 0  1347508753520680962            @ItsMeKande අඩෝ Nazi Naran Hybrid ද ? 😂
# 1  1360929538717274115  @Jude_H_Fernando අඩෝ කොලුකාර ජුඩා bro many hap...
# 2  1368467258196914176  අපිට අද දවසේ මේ වගේ ආතල් එකක් දුන්නට Ex ලට ගොඩ...
# 3  1366583603610591237  @EnThunga මන් පාවිච්චි කරන්නෙ Sony WF-1000XM3....
# 4  1366256111167307779         @gim_Rathnayaka_ @sasini0211 අඩෝ අඩෝ එපා 😅
#
#    truncated display_text_range  \
# ...

# %%
rows = data.shape[0]

# %%
rows
# Out:
# 331

# %%
labelColumnData = [label for i in range(rows) ]

# %%
data['label'] = labelColumnData

# %%
data.head()
# Out:
#             Unnamed: 0                      created_at                   id  \
# 0  1347508753520680962  Fri Jan 08 11:41:36 +0000 2021  1347508753520680962
# 1  1360929538717274115  Sun Feb 14 12:31:01 +0000 2021  1360929538717274115
# 2  1368467258196914176  Sun Mar 07 07:43:13 +0000 2021  1368467258196914176
# 3  1366583603610591237  Tue Mar 02 02:58:15 +0000 2021  1366583603610591237
# 4  1366256111167307779  Mon Mar 01 05:16:55 +0000 2021  1366256111167307779
#
#                 id_str                                          full_text  \
# 0  1347508753520680962            @ItsMeKande අඩෝ Nazi Naran Hybrid ද ? 😂
# 1  1360929538717274115  @Jude_H_Fernando අඩෝ කොලුකාර ජුඩා bro many hap...
# 2  1368467258196914176  අපිට අද දවසේ මේ වගේ ආතල් එකක් දුන්නට Ex ලට ගොඩ...
# 3  1366583603610591237  @EnThunga මන් පාවිච්චි කරන්නෙ Sony WF-1000XM3....
# 4  1366256111167307779         @gim_Rathnayaka_ @sasini0211 අඩෝ අඩෝ එපා 😅
#
#    truncated display_text_range  \
# ...

# %%
data.to_csv("./labelled/"+fileName)
