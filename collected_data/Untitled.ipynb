# %%
import pandas as pd
import csv

# %%
import glob
path_csv=glob.glob("*.csv")

# %%
path_csv
# Out:
# ['dataset11_පයිය.csv',
#  'dataset_දක්ෂ.csv',
#  'dataset_භාවනා.csv',
#  'dataset_භාවනා .csv',
#  'dataset12_හුකන්න.csv',
#  'dataset_නියමයි.csv',
#  'dataset7_වේසි.csv',
#  'dataset_අම්මා.csv',
#  'dataset_ලස්සනයි.csv',
#  'dataset.csv',
#  'dataset_ගුරුවරයා.csv',
#  'dataset4_පොන්නයො.csv',
#  'dataset9_කාලකන්නි.csv',
#  'dataset_තාත්තා.csv',
#  'dataset10_කිම්බ.csv',
#  'dataset_කරුණාව.csv',
#  'merged_data.csv',
#  'dataset6_බැල්ලි.csv',
#  'dataset_ආදරෙයි.csv',
#  'dataset_ගෙදර.csv',
#  'dataset_යාලුවා.csv',
#  'dataset1.csv',
#  'dataset_සුපිරි.csv',
#  'dataset5_පකයා.csv',
#  'dataset2_අඩෝ.csv',
#  'dataset3_හුත්ති.csv',
#  'dataset8_කැරියා.csv']

# %%
f1=pd.read_csv("dataset3_හුත්ති.csv")
f2=pd.read_csv("dataset4_පොන්නයො.csv")
f3=pd.read_csv("dataset5_පකයා.csv")
f4=pd.read_csv("dataset6_බැල්ලි.csv")
f5=pd.read_csv("dataset7_වේසි.csv")
f6=pd.read_csv("dataset8_කැරියා.csv")
f7=pd.read_csv("dataset9_කාලකන්නි.csv")
f8=pd.read_csv("dataset10_කිම්බ.csv")
f9=pd.read_csv("dataset11_පයිය.csv")
f10=pd.read_csv("dataset12_හුකන්න.csv")
f11=pd.read_csv("dataset_සුපිරි.csv")
f12=pd.read_csv("dataset_යාලුවා.csv")
f13=pd.read_csv("dataset_ලස්සනයි.csv")
f14=pd.read_csv("dataset_නියමයි.csv")
f15=pd.read_csv("dataset_ආදරෙයි.csv")
f16=pd.read_csv("dataset_ගුරුවරයා.csv")
f17=pd.read_csv("dataset_අම්මා.csv")
f18=pd.read_csv("dataset_ගෙදර.csv")
f19=pd.read_csv("dataset_දක්ෂ.csv")
f20=pd.read_csv("dataset_තාත්තා.csv")
f21=pd.read_csv("dataset_කරුණාව.csv")
f22=pd.read_csv("dataset_භාවනා.csv")

merged=pd.concat([f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17,f18,f19,f20,f21,f22])

# %%
f22.shape
# Out:
# (264, 39)

# %%
f21.shape
# Out:
# (255, 39)

# %%
f16.shape
# Out:
# (226, 41)

# %%
merged.shape
# Out:
# (5258, 41)

# %%
merged.head(5)
# Out:
#             Unnamed: 0                      created_at                   id  \
# 0  1266836678720860164  Sat May 30 20:59:35 +0000 2020  1266836678720860164
# 1  1239444926074478592  Mon Mar 16 06:54:32 +0000 2020  1239444926074478592
# 2  1076416174349533184  Sat Dec 22 09:56:29 +0000 2018  1076416174349533184
# 3  1308628330233491457  Wed Sep 23 04:44:41 +0000 2020  1308628330233491457
# 4  1323597495407030272  Tue Nov 03 12:06:48 +0000 2020  1323597495407030272
#
#                 id_str                                          full_text  \
# 0  1266836678720860164  ma mer ça fait longtem ell m’a pa traitée de හ...
# 1  1239444926074478592                   වැස්සියො https://t.co/OhpSBWqJrH
# 2  1076416174349533184  මේ හුත්ති කියන ගණන්නම් මට තේරෙන්නෙ නෑ. උබලට තේ...
# 3  1308628330233491457  @Nikshazz අපේ කාඩිනල් හිමි පානන්ට මගේ ජේසුට අප...
# 4  1323597495407030272  දැන් සැප ඇතිනේද අර වොයිස් නෝට් එක ඇහුවට පස්සේ?...
#
#    truncated display_text_range  \
# ...

# %%
a =merged['id'].unique()

# %%
len(a)
# Out:
# 5176

# %%
duplicate = merged[merged.duplicated('id')]

# %%
duplicate
# Out:
#               Unnamed: 0                      created_at                   id  \
# 130  1156128904631005184  Tue Jul 30 09:06:25 +0000 2019  1156128904631005184
# 210  1320398301007548417  Sun Oct 25 16:14:21 +0000 2020  1320398301007548417
# 254  1320400653160570882  Sun Oct 25 16:23:42 +0000 2020  1320400653160570882
# 5    1308628330233491457  Wed Sep 23 04:44:41 +0000 2020  1308628330233491457
# 37   1280124523547783169  Mon Jul 06 13:00:44 +0000 2020  1280124523547783169
# ..                   ...                             ...                  ...
# 143  1394624061582446594  Tue May 18 12:01:01 +0000 2021  1394624061582446594
# 144  1395615202616516609  Fri May 21 05:39:28 +0000 2021  1395615202616516609
# 145  1394628604340760587  Tue May 18 12:19:04 +0000 2021  1394628604340760587
# 146  1394950845540618240  Wed May 19 09:39:33 +0000 2021  1394950845540618240
# 66   1371101397094109189  Sun Mar 14 14:10:21 +0000 2021  1371101397094109189
#
# ...

# %%
# dropping ALL duplicte values
merged.drop_duplicates(subset ="id",
                     keep = False, inplace = True)

# %%
merged.shape
# Out:
# (5098, 41)

# %%
duplicate = merged[merged.duplicated('id')]

# %%
duplicate
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, created_at, id, id_str, full_text, truncated, display_text_range, entities, source, in_reply_to_status_id, in_reply_to_status_id_str, in_reply_to_user_id, in_reply_to_user_id_str, in_reply_to_screen_name, user_id, user_id_str, geo, coordinates, place, contributors, is_quote_status, retweet_count, favorite_count, reply_count, quote_count, conversation_id, conversation_id_str, favorited, retweeted, lang, supplemental_language, extended_entities, possibly_sensitive, possibly_sensitive_editable, self_thread, quoted_status_id, quoted_status_id_str, quoted_status_permalink, card, conversation_control, limited_actions]
# Index: []
#
# [0 rows x 41 columns]

# %%
merged.to_csv("merged_data.csv")
